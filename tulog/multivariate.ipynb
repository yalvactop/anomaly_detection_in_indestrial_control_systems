# %% [markdown]
# # Using Orion on Multivariate Input
#
# In this notebook, we demonstrate how you can use multivariate time series in Orion. We will walk through the process using NASA's dataset, you can find the original data in [Telemanom](https://github.com/khundman/telemanom) github or directly from their [S3 bucket](https://s3-us-west-2.amazonaws.com/telemanom/data.zip).

# %% [markdown]
# ## 1. Load the data
#
# In the first step, we setup the environment and load the CSV that we want to process.
#
# To do so, we need to import the `orion.data.load_signal` function and call it passing
# the path to the CSV file.
#
# In this case, we will be loading the `S-1.csv` file from inside the `data/multivariate` folder.

# %%
from orion.data import load_signal

# signal_path = 'multivariate/S-1'

# data = load_signal(signal_path)
# data.head()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('swat.csv')
data.head(5)
# Out:
#              timestamp    FIT101    LIT101   MV101  P101  P102    AIT201  \
# 0  1451296800000000000  2.427057  522.8467       2     2     1  262.0161
# 1  1451296801000000000  2.446274  522.8860       2     2     1  262.0161
# 2  1451296802000000000  2.489191  522.8467       2     2     1  262.0161
# 3  1451296803000000000  2.534350  522.9645       2     2     1  262.0161
# 4  1451296804000000000  2.569260  523.4748       2     2     1  262.0161
#
#      AIT202    AIT203    FIT201  ...  P501  P502    PIT501    PIT502  \
# 0  8.396437  328.6337  2.445391  ...     2     1  250.8652  1.649953
# 1  8.396437  328.6337  2.445391  ...     2     1  250.8652  1.649953
# 2  8.394514  328.6337  2.442316  ...     2     1  250.8812  1.649953
# 3  8.394514  328.6337  2.442316  ...     2     1  250.8812  1.649953
# 4  8.394514  328.6337  2.443085  ...     2     1  250.8812  1.649953
#
#      PIT503    FIT601  P601  P602  P603  Normal/Attack
# 0  189.5988  0.000128     1     1     1         Normal
# 1  189.6789  0.000128     1     1     1         Normal
# 2  189.6789  0.000128     1     1     1         Normal
# 3  189.6148  0.000128     1     1     1         Normal
# 4  189.5027  0.000128     1     1     1         Normal
#
# [5 rows x 53 columns]

# %% [markdown]
# ## 2. Detect anomalies using Orion
#
# Once we have the data, let us try to use the LSTM pipeline to analyze it and search for anomalies.
#
# In order to do so, we will import the `Orion` class from `orion.core` and pass it
# the loaded data and the path to the pipeline JSON that we want to use.
#
# In this case, we will be using the `lstm_dynamic_threshold` pipeline from inside the `orion` folder.
#
# In addition, we setup the hyperparameters to correctly identify the signal we are trying to predict. In this case, dimension `0` is the signal value and such we set `target_column` to `0`. Note that `0` refers to the location of the channel rather than the name.

# %%
from orion import Orion

hyperparameters = {
    "mlprimitives.custom.timeseries_preprocessing.rolling_window_sequences#1": {
        'target_column': 0 
    },
    'keras.Sequential.LSTMTimeSeriesRegressor#1': {
        'epochs': 5,
        'verbose': True
    }
}

orion = Orion(
    pipeline='lstm_dynamic_threshold',
    hyperparameters=hyperparameters
)

orion.fit(data.iloc[:7500])
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5293/3036436641.py in <module>
#      16 )
#      17
# ---> 18 orion.fit(data.iloc[:7500])
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/orion/core.py in fit(self, data)
#      82         """
#      83         self._mlpipeline = self._get_mlpipeline()
# ---> 84         self._mlpipeline.fit(data)
#      85         self._fitted = True
#      86
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/mlblocks/mlpipeline.py in fit(self, X, y, output_, start_, **kwargs)
#     650
#     651             if (block_name != self._last_block_name) or (block_name in output_blocks):
# --> 652                 self._produce_block(block, block_name, context, output_variables, outputs)
#     653
#     654                 # We already captured the output from this block
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/mlblocks/mlpipeline.py in _produce_block(self, block, block_name, context, output_variables, outputs)
#     563         try:
#     564             produce_args = self._get_block_args(block_name, block.produce_args, context)
# --> 565             block_outputs = block.produce(**produce_args)
#     566
#     567             outputs_dict = self._extract_outputs(block_name, block_outputs, block.produce_output)
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/mlblocks/mlblock.py in produce(self, **kwargs)
#     323
#     324         produce_kwargs.update(self.get_hyperparameters())
# --> 325         return self.primitive(**produce_kwargs)
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/mlprimitives/custom/timeseries_preprocessing.py in time_segments_aggregate(X, interval, time_column, method)
#     191     while start_ts <= max_ts:
#     192         end_ts = start_ts + interval
# --> 193         subset = X.loc[start_ts:end_ts - 1]
#     194         aggregated = [
#     195             getattr(subset, agg)(skipna=True).values
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1865         if isinstance(key, slice):
#    1866             self._validate_key(key, axis)
# -> 1867             return self._get_slice_axis(key, axis=axis)
#    1868         elif com.is_bool_indexer(key):
#    1869             return self._getbool_axis(key, axis=axis)
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1534
#    1535         if isinstance(indexer, slice):
# -> 1536             return self._slice(indexer, axis=axis, kind='iloc')
#    1537         else:
#    1538             return self.obj._take(indexer, axis=axis)
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/pandas/core/indexing.py in _slice(self, obj, axis, kind)
#     149         if axis is None:
#     150             axis = self.axis
# --> 151         return self.obj._slice(obj, axis=axis, kind=kind)
#     152
#     153     def _get_setitem_indexer(self, key):
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/pandas/core/generic.py in _slice(self, slobj, axis, kind)
#    3160         """
#    3161         axis = self._get_block_manager_axis(axis)
# -> 3162         result = self._constructor(self._data.get_slice(slobj, axis=axis))
#    3163         result = result.__finalize__(self)
#    3164
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/pandas/core/internals/managers.py in get_slice(self, slobj, axis)
#     692             slicer[axis] = slobj
#     693             slicer = tuple(slicer)
# --> 694             new_blocks = [blk.getitem_block(slicer) for blk in self.blocks]
#     695
#     696         new_axes = list(self.axes)
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     692             slicer[axis] = slobj
#     693             slicer = tuple(slicer)
# --> 694             new_blocks = [blk.getitem_block(slicer) for blk in self.blocks]
#     695
#     696         new_axes = list(self.axes)
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/pandas/core/internals/blocks.py in getitem_block(self, slicer, new_mgr_locs)
#     293             else:
#     294                 axis0_slicer = slicer
# --> 295             new_mgr_locs = self.mgr_locs[axis0_slicer]
#     296
#     297         new_values = self._slice(slicer)
#
# pandas/_libs/internals.pyx in pandas._libs.internals.BlockPlacement.__getitem__()
#
# pandas/_libs/internals.pyx in pandas._libs.internals.BlockPlacement.__init__()
#
# ~/.pyenv/versions/3.7.12/lib/python3.7/site-packages/numpy/core/numeric.py in require(a, dtype, requirements)
#     764         requirements.remove('C')
#     765
# --> 766     arr = array(a, dtype=dtype, order=order, copy=False, subok=subok)
#     767
#     768     for prop in requirements:
#
# KeyboardInterrupt:

# %% [markdown]
# The output will be a ``pandas.DataFrame`` containing a table with the detected anomalies.

# %%
orion.detect(data)

# %% [markdown]
# For reconstruction based pipelines, we need to specify the shape of the **input** and **target** sequences. For example, assume we are using the `lstm_autoencoder` pipeline, we set the hyperparameter values
#
# ```python3
# hyperparameters = {
#     "mlprimitives.custom.timeseries_preprocessing.rolling_window_sequences#1": {
#         'window_size': 100,
#         'target_column': 0
#     },
#     'keras.Sequential.LSTMSeq2Seq#1': {
#         'epochs': 5,
#         'verbose': True,
#         'input_shape': [100, 25],
#         'target_shape': [100, 1],
#     }
# }
# ```
#
# where the shape of the input is dependent on
#
# 1. `window_size` and
# 2. the number of channels in the data.
#
# Similarly, the shape of the output is dependent on the `window_size`. Currently, we are focusing on multivariate input and univariate output, therefore the target shape should always be [`window_size`, 1].

# %%
hyperparameters = {
    "mlprimitives.custom.timeseries_preprocessing.rolling_window_sequences#1": {
        "window_size": 100,
        "target_column": 0 
    },
    'keras.Sequential.LSTMSeq2Seq#1': {
        'epochs': 5,
        'verbose': True,
        'input_shape': [100, 51],
        'target_shape': [100, 1],
    }
}

orion = Orion(
    pipeline='lstm_autoencoder',
    hyperparameters=hyperparameters
)

orion.fit(data)

# %% [markdown]
# TadGAN is also a reconstruction based pipeline, thus we specify the `input_shape` to be of multivariate shape as needed.
#
# ```python3
# hyperparameters = {
#     'orion.primitives.tadgan.TadGAN#1': {
#         'epochs': 5,
#         'verbose': True,
#         'input_shape': [100, 25]
#     }
# }
# ```
